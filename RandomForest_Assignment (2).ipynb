# %%
#Import required liabraries
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline

plt.rcParams['figure.figsize']=(18,10)
plt.rcParams['figure.dpi']=300

# %%
file=pd.ExcelFile('glass[1].xlsx')
df=pd.read_excel(file, 'glass')

# %%
df
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe  Type
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0     1
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0     1
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0     1
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0     1
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0     1
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...   ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0     7
#
# [214 rows x 10 columns]

# %% [markdown]
# # EDA

# %%
df.shape
# Out:
# (214, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 214 entries, 0 to 213
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   RI      214 non-null    float64
#  1   Na      214 non-null    float64
#  2   Mg      214 non-null    float64
#  3   Al      214 non-null    float64
#  4   Si      214 non-null    float64
#  5   K       214 non-null    float64
#  6   Ca      214 non-null    float64
#  7   Ba      214 non-null    float64
#  8   Fe      214 non-null    float64
#  9   Type    214 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 16.8 KB

# %%
df.describe()
# Out:
#                RI          Na          Mg          Al          Si           K  \
# count  214.000000  214.000000  214.000000  214.000000  214.000000  214.000000
# mean     1.518365   13.407850    2.684533    1.444907   72.650935    0.497056
# std      0.003037    0.816604    1.442408    0.499270    0.774546    0.652192
# min      1.511150   10.730000    0.000000    0.290000   69.810000    0.000000
# 25%      1.516522   12.907500    2.115000    1.190000   72.280000    0.122500
# 50%      1.517680   13.300000    3.480000    1.360000   72.790000    0.555000
# 75%      1.519157   13.825000    3.600000    1.630000   73.087500    0.610000
# max      1.533930   17.380000    4.490000    3.500000   75.410000    6.210000
#
#                Ca          Ba          Fe        Type
# count  214.000000  214.000000  214.000000  214.000000
# mean     8.956963    0.175047    0.057009    2.780374
# std      1.423153    0.497219    0.097439    2.103739
# ...

# %%
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 1

# %%
df[df.duplicated()]
# Out:
#          RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 39  1.52213  14.21  3.82  0.47  71.77  0.11  9.57  0.0  0.0     1

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (213, 10)

# %% [markdown]
# # Data Visulization

# %%
df['Type'].unique()
# Out:
# array([1, 2, 3, 5, 6, 7])

# %%
df['Type'].value_counts()
# Out:
# Type
# 2    76
# 1    69
# 7    29
# 3    17
# 5    13
# 6     9
# Name: count, dtype: int64

# %%
sns.countplot(data=df, x='Type')
# Out:
# <Axes: xlabel='Type', ylabel='count'>

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'RI'}>, <Axes: title={'center': 'Na'}>,
#         <Axes: title={'center': 'Mg'}>],
#        [<Axes: title={'center': 'Al'}>, <Axes: title={'center': 'Si'}>,
#         <Axes: title={'center': 'K'}>],
#        [<Axes: title={'center': 'Ca'}>, <Axes: title={'center': 'Ba'}>,
#         <Axes: title={'center': 'Fe'}>],
#        [<Axes: title={'center': 'Type'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
sns.pairplot(df)

# %%
df.boxplot()
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#             RI        Na        Mg        Al        Si         K        Ca  \
# RI    1.000000 -0.198802 -0.127526 -0.400973 -0.539000 -0.287645  0.811183
# Na   -0.198802  1.000000 -0.278420  0.167735 -0.064885 -0.264158 -0.278194
# Mg   -0.127526 -0.278420  1.000000 -0.479575 -0.162437  0.007617 -0.446197
# Al   -0.400973  0.167735 -0.479575  1.000000 -0.016195  0.323683 -0.258068
# Si   -0.539000 -0.064885 -0.162437 -0.016195  1.000000 -0.197281 -0.207145
# K    -0.287645 -0.264158  0.007617  0.323683 -0.197281  1.000000 -0.317032
# Ca    0.811183 -0.278194 -0.446197 -0.258068 -0.207145 -0.317032  1.000000
# Ba    0.001679  0.329080 -0.491818  0.480642 -0.104389 -0.043653 -0.112208
# Fe    0.147083 -0.239374  0.085426 -0.080583 -0.097717 -0.009372  0.126314
# Type -0.160140  0.508837 -0.744195  0.597432  0.147725 -0.012455  0.002677
#
#             Ba        Fe      Type
# RI    0.001679  0.147083 -0.160140
# Na    0.329080 -0.239374  0.508837
# Mg   -0.491818  0.085426 -0.744195
# ...

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Split Dataset

# %%
x=df.iloc[ : , :-1]
y=df.iloc[ : ,-1]

# %%
x
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba   Fe
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.0
# 1    1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.00  0.0
# 2    1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.00  0.0
# 3    1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.00  0.0
# 4    1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.00  0.0
# ..       ...    ...   ...   ...    ...   ...   ...   ...  ...
# 209  1.51623  14.14  0.00  2.88  72.61  0.08  9.18  1.06  0.0
# 210  1.51685  14.92  0.00  1.99  73.06  0.00  8.40  1.59  0.0
# 211  1.52065  14.36  0.00  2.02  73.42  0.00  8.44  1.64  0.0
# 212  1.51651  14.38  0.00  1.94  73.61  0.00  8.48  1.57  0.0
# 213  1.51711  14.23  0.00  2.08  73.36  0.00  8.62  1.67  0.0
#
# [213 rows x 9 columns]

# %%
y
# Out:
# 0      1
# 1      1
# 2      1
# 3      1
# 4      1
#       ..
# 209    7
# 210    7
# 211    7
# 212    7
# 213    7
# Name: Type, Length: 213, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain, xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2,random_state=45)

# %%
xtrain
# Out:
#           RI     Na    Mg    Al     Si     K    Ca    Ba    Fe
# 118  1.51673  13.30  3.64  1.53  72.53  0.65  8.03  0.00  0.29
# 68   1.52152  13.12  3.58  0.90  72.20  0.23  9.82  0.00  0.16
# 102  1.51820  12.62  2.76  0.83  73.81  0.35  9.42  0.00  0.20
# 0    1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.00  0.00
# 62   1.52172  13.51  3.86  0.88  71.79  0.23  9.54  0.00  0.11
# ..       ...    ...   ...   ...    ...   ...   ...   ...   ...
# 32   1.51775  12.85  3.48  1.23  72.97  0.61  8.56  0.09  0.22
# 125  1.51872  12.93  3.66  1.56  72.51  0.58  8.55  0.00  0.12
# 132  1.51813  13.43  3.98  1.18  72.49  0.58  8.15  0.00  0.00
# 159  1.51796  13.50  3.36  1.63  71.94  0.57  8.81  0.00  0.09
# 204  1.51617  14.95  0.00  2.27  73.30  0.00  8.71  0.67  0.00
#
# [170 rows x 9 columns]

# %%
ytrain
# Out:
# 118    2
# 68     1
# 102    2
# 0      1
# 62     1
#       ..
# 32     1
# 125    2
# 132    2
# 159    3
# 204    7
# Name: Type, Length: 170, dtype: int64

# %%
xtest
# Out:
#           RI     Na    Mg    Al     Si     K     Ca    Ba    Fe
# 84   1.51409  14.25  3.09  2.08  72.28  1.10   7.08  0.00  0.00
# 63   1.52227  14.17  3.81  0.78  71.35  0.00   9.69  0.00  0.00
# 85   1.51625  13.36  3.58  1.49  72.72  0.45   8.21  0.00  0.00
# 138  1.51674  12.79  3.52  1.54  73.36  0.66   7.90  0.00  0.00
# 188  1.52247  14.86  2.20  2.06  70.26  0.76   9.76  0.00  0.00
# 75   1.51590  13.02  3.58  1.51  73.12  0.69   7.96  0.00  0.00
# 51   1.51926  13.20  3.33  1.28  72.36  0.60   9.14  0.00  0.11
# 157  1.52121  14.03  3.76  0.58  71.79  0.11   9.65  0.00  0.00
# 207  1.51831  14.39  0.00  1.82  72.86  1.41   6.47  2.88  0.00
# 92   1.51588  13.12  3.41  1.58  73.26  0.07   8.39  0.00  0.19
# 162  1.52211  14.19  3.78  0.91  71.36  0.23   9.14  0.00  0.37
# 33   1.51753  12.57  3.47  1.38  73.39  0.60   8.55  0.00  0.06
# 139  1.51674  12.87  3.56  1.64  73.14  0.65   7.99  0.00  0.00
# 3    1.51766  13.21  3.69  1.29  72.61  0.57   8.22  0.00  0.00
# ...

# %%
ytest
# Out:
# 84     2
# 63     1
# 85     2
# 138    2
# 188    7
# 75     2
# 51     1
# 157    3
# 207    7
# 92     2
# 162    3
# 33     1
# 139    2
# 3      1
# 25     1
# 100    2
# 41     1
# 151    3
# 160    3
# 13     1
# 201    7
# 101    2
# 196    7
# 74     2
# 70     2
# 148    3
# 65     1
# 95     2
# 130    2
# 80     2
# 192    7
# 140    2
# 26     1
# 45     1
# 149    3
# 123    2
# 195    7
# 38     1
# 81     2
# 83     2
# 133    2
# 161    3
# 10     1
# Name: Type, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler
std=StandardScaler()
xtrain_scaled=std.fit_transform(xtrain)
xtrain_scaled
# Out:
# array([[-0.54876988, -0.12174248,  0.70459028, ..., -0.66206846,
#         -0.37799264,  2.32342199],
#        [ 0.95273649, -0.33449633,  0.66417174, ...,  0.50973071,
#         -0.37799264,  1.017199  ],
#        [-0.08797356, -0.92547924,  0.11178501, ...,  0.24787615,
#         -0.37799264,  1.41911376],
#        ...,
#        [-0.10991624,  0.03191308,  0.93362868, ..., -0.58351209,
#         -0.37799264, -0.59046008],
#        [-0.16320561,  0.11465069,  0.51597042, ..., -0.15145206,
#         -0.37799264,  0.31384815],
#        [-0.72431133,  1.82850113, -1.7474679 , ..., -0.2169157 ,
#          0.94672619, -0.59046008]])

# %%
xtest_scaled=std.fit_transform(xtest)
xtest_scaled
# Out:
# array([[-1.70849153e+00,  1.24329763e+00,  6.22169175e-02,
#          1.24922495e+00, -4.41272715e-01,  1.25890606e+00,
#         -1.89744125e+00, -2.52903933e-01, -5.83753884e-01],
#        [ 2.03594620e+00,  1.12511736e+00,  6.66052580e-01,
#         -1.46163199e+00, -1.61535760e+00, -1.22322218e+00,
#          1.34133946e+00, -2.52903933e-01, -5.83753884e-01],
#        [-7.19740248e-01, -7.14578356e-02,  4.73160633e-01,
#          1.89129555e-02,  1.14208307e-01, -2.07806085e-01,
#         -4.95210523e-01, -2.52903933e-01, -5.83753884e-01],
#        [-4.95440189e-01, -9.13492235e-01,  4.22840994e-01,
#          1.23176684e-01,  9.22180703e-01,  2.66054761e-01,
#         -8.79893289e-01, -2.52903933e-01, -5.83753884e-01],
#        [ 2.12749724e+00,  2.14442216e+00, -6.84191055e-01,
#          1.20751946e+00, -2.99143559e+00,  4.91702782e-01,
#          1.42820331e+00, -2.52903933e-01, -5.83753884e-01],
#        [-8.79954577e-01, -5.73723968e-01,  4.73160633e-01,
# ...

# %% [markdown]
# # Random Forest Model Building

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
Rmodel=RandomForestClassifier(n_estimators=100, random_state=10)
Rmodel.fit(xtrain_scaled, ytrain)
# Out:
# RandomForestClassifier(random_state=10)

# %%
y_pred=Rmodel.predict(xtest_scaled)

# %%
y_pred
# Out:
# array([7, 1, 2, 2, 2, 2, 1, 1, 7, 2, 1, 1, 2, 1, 1, 2, 1, 1, 2, 1, 5, 5,
#        7, 2, 6, 3, 2, 1, 2, 2, 7, 2, 1, 1, 2, 2, 7, 1, 1, 2, 2, 2, 2])

# %%
from sklearn.metrics import accuracy_score,precision_score,f1_score,recall_score

# %%
print('accuracy=',accuracy_score(ytest,y_pred)*100)
# Out:
# accuracy= 65.11627906976744

# %%
print('Precision=',precision_score(ytest,y_pred,average='weighted')*100)
print('F1=',f1_score(ytest,y_pred,average='weighted')*100)
print('Recall=',recall_score(ytest,y_pred,average='weighted')*100)
# Out:
# Precision= 74.68788249694003
# F1= 64.30505558412534
# Recall= 65.11627906976744

# %% [markdown]
# # Bagging and Boosting

# %%
from sklearn.ensemble import BaggingClassifier,AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#Bagging
cart=DecisionTreeClassifier()
bagg=BaggingClassifier(estimator=cart,n_estimators=100,random_state=0)

# %%
bagg.fit(xtrain_scaled,ytrain)
# Out:
# BaggingClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                   random_state=0)

# %%
ypred_Ba=bagg.predict(xtest_scaled)
ypred_Ba
# Out:
# array([1, 1, 2, 2, 2, 2, 1, 1, 7, 2, 1, 1, 2, 1, 1, 5, 1, 1, 2, 1, 5, 5,
#        7, 1, 1, 2, 2, 1, 2, 2, 7, 2, 1, 1, 3, 2, 7, 1, 1, 2, 2, 2, 1])

# %%
from sklearn.metrics import classification_report

# %%
print(classification_report(ytest,ypred_Ba))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.58      0.92      0.71        12
#            2       0.69      0.61      0.65        18
#            3       1.00      0.14      0.25         7
#            5       0.00      0.00      0.00         0
#            7       1.00      0.67      0.80         6
#
#     accuracy                           0.63        43
#    macro avg       0.65      0.47      0.48        43
# weighted avg       0.75      0.63      0.62        43

# %%
#Boosting
boost=AdaBoostClassifier(estimator=cart,n_estimators=100,random_state=2)
boost.fit(xtrain_scaled, ytrain)
# Out:
# AdaBoostClassifier(estimator=DecisionTreeClassifier(), n_estimators=100,
#                    random_state=2)

# %%
ypred_bo=boost.predict(xtest_scaled)

# %%
print(classification_report(ytest,ypred_bo))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.38      0.50      0.43        12
#            2       0.42      0.44      0.43        18
#            3       0.50      0.14      0.22         7
#            5       0.00      0.00      0.00         0
#            7       1.00      0.67      0.80         6
#
#     accuracy                           0.44        43
#    macro avg       0.46      0.35      0.38        43
# weighted avg       0.50      0.44      0.45        43

# %%
from lightgbm import LGBMClassifier

# %% [markdown]
# **Compare the Accuracies of models**

# %%
lgb_model = LGBMClassifier()
lgb_model.fit(xtest,ytest)

# Validate the model
y_pred_lgb = lgb_model.predict(xtest)
y_pred_lgb
# Out:
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000040 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 102
# [LightGBM] [Info] Number of data points in the train set: 43, number of used features: 7
# [LightGBM] [Info] Start training from score -1.276293
# [LightGBM] [Info] Start training from score -0.870828
# [LightGBM] [Info] Start training from score -1.815290
# [LightGBM] [Info] Start training from score -1.969441
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# ...

# %% [markdown]
# Random Forest<Bagging<Adaboostclassifier

# %%
print("LightGBM Model Training Accuracy:", accuracy_score(ytest, y_pred_lgb))
# Out:
# LightGBM Model Training Accuracy: 0.813953488372093
